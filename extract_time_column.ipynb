# %%
# edit line 7
import pandas as pd
import ast
import os

# Directory containing the CSV files
input_directory = 'E:/intern_work_testing/label_obj'

# Function to extract time data from cropped_data column
def extract_time_data(cropped_data_str):
    # Parse the string as a list of dictionaries
    data_list = ast.literal_eval(cropped_data_str)
    # Extract the 'time' field from each dictionary
    time_data = [point['time'] for point in data_list]
    return time_data

# Process each CSV file in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.csv'):
        # Read the CSV file into a pandas DataFrame
        file_path = os.path.join(input_directory, filename)
        df = pd.read_csv(file_path)

        # Apply the function to extract 'time' data from the cropped_data column
        df['cropped_data'] = df['cropped_data'].apply(extract_time_data)

        # Overwrite the original file with the modified data
        df.to_csv(file_path, index=False)

        print(f"Processed and updated {filename}, modified cropped_data column.")
# Out:
# Processed and updated 000000.csv, modified cropped_data column.
# Processed and updated 000001.csv, modified cropped_data column.
# Processed and updated 000002.csv, modified cropped_data column.
# Processed and updated 000003.csv, modified cropped_data column.
# Processed and updated 000004.csv, modified cropped_data column.
# Processed and updated 000005.csv, modified cropped_data column.
# Processed and updated 000006.csv, modified cropped_data column.
# Processed and updated 000007.csv, modified cropped_data column.
# Processed and updated 000008.csv, modified cropped_data column.
# Processed and updated 000009.csv, modified cropped_data column.
# Processed and updated 000010.csv, modified cropped_data column.
# Processed and updated 000011.csv, modified cropped_data column.
# Processed and updated 000012.csv, modified cropped_data column.
# Processed and updated 000013.csv, modified cropped_data column.
# Processed and updated 000014.csv, modified cropped_data column.
# ...
